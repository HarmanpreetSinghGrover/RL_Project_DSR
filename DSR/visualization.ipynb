# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
k = np.loadtxt('test.out')

plt.plot(k[0,:]); plt.title('reward per episode'); plt.show()
plt.plot(k[1,:]); plt.title('episode time'); plt.show()

eps = 0.05 + (0.99-0.05) * np.exp(-np.sum(k[1,:])/100000)
print('eps = {}'.format(eps))
# Out:
# eps = 0.06175736526484227
